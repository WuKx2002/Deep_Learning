# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.random.random(size = 5)
print(y)

# %%
x = range(5)

# %%
plt.plot(x)
plt.show()

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.show( )

# %%
#深度学习训练
#1、训练准确率 2、验证准确率

# %%
#在一个图表内绘制两条曲线

# %%
y1 = np.random.random(size = 10)
y2 = y1 + 3
print(y1)
print(y2)
# Out:
# [0.80414549 0.94162634 0.27059986 0.47346537 0.55879156 0.57807616
#  0.13858878 0.48343451 0.33591353 0.30951838]
# [3.80414549 3.94162634 3.27059986 3.47346537 3.55879156 3.57807616
#  3.13858878 3.48343451 3.33591353 3.30951838]

# %%
x1 = range(10)
x2 = range(10)

# %%
plt.plot(x1, y1)
plt.plot(x1, y2)

plt.show( )
